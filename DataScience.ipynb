# %%
import pandas as pd
import numpy as ny

import matplotlib.pyplot as plp

import seaborn as sns

dataPath = "C:/Users/Anwender/Documents/GitHub/DataScienceProject/DataLib/candy.csv"

dataCandy = pd.read_csv(dataPath)

sns.swarmplot(data = dataCandy)
# Out:
# c:\Users\Anwender\anaconda3\envs\DataScience\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 79.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: >
# c:\Users\Anwender\anaconda3\envs\DataScience\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 84.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
